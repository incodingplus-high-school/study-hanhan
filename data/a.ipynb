# %%
import os

def file(path:str):
    li = os.listdir(path)
    for i in li:
        a = os.path.join(path,i)
        if os.path.isdir(a):
            file(a)
        else:
            print(a)
file('/Users/yudoh')
# Out:
# /Users/yudoh\.gitconfig
# /Users/yudoh\.idlerc\recent-files.lst
# /Users/yudoh\.ipython\profile_default\db\dhist
# /Users/yudoh\.ipython\profile_default\history.sqlite
# /Users/yudoh\.ipython\profile_default\history.sqlite-journal
# /Users/yudoh\.ipython\profile_default\startup\README
# /Users/yudoh\.vscode\argv.json
# /Users/yudoh\.vscode\extensions\.init-default-profile-extensions
# /Users/yudoh\.vscode\extensions\.obsolete
# /Users/yudoh\.vscode\extensions\extensions.json
# /Users/yudoh\.vscode\extensions\ms-ceintl.vscode-language-pack-ko-1.75.2023020809\.vsixmanifest
# /Users/yudoh\.vscode\extensions\ms-ceintl.vscode-language-pack-ko-1.75.2023020809\CHANGELOG.md
# /Users/yudoh\.vscode\extensions\ms-ceintl.vscode-language-pack-ko-1.75.2023020809\languagepack.png
# /Users/yudoh\.vscode\extensions\ms-ceintl.vscode-language-pack-ko-1.75.2023020809\package.json
# /Users/yudoh\.vscode\extensions\ms-ceintl.vscode-language-pack-ko-1.75.2023020809\README.md
# ...
